# %%
import pandas as pd

# %%
url = 'https://movie.naver.com/movie/sdb/rank/rmovie.nhn'

# %%
tables = pd.read_html(url)
tables
# Out:
# [    순위                 영화명  변동폭  변동폭.1  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
#  0  NaN                 NaN  NaN    NaN         NaN         NaN         NaN
#  1  NaN              블랙 위도우  NaN    0.0         NaN         NaN         NaN
#  2  NaN                발신제한  NaN    0.0         NaN         NaN         NaN
#  3  NaN                  랑종  NaN    0.0         NaN         NaN         NaN
#  4  NaN               미드나이트  NaN    1.0         NaN         NaN         NaN
#  5  NaN                크루엘라  NaN    1.0         NaN         NaN         NaN
#  6  NaN             인 더 하이츠  NaN    2.0         NaN         NaN         NaN
#  7  NaN         콰이어트 플레이스 2  NaN    0.0         NaN         NaN         NaN
#  8  NaN          킬러의 보디가드 2  NaN    0.0         NaN         NaN         NaN
#  9  NaN              제8일의 밤  NaN    0.0         NaN         NaN         NaN
#  10 NaN                  루카  NaN    0.0         NaN         NaN         NaN
# ...

# %%
tables[0]
# Out:
#     순위                 영화명  변동폭  변동폭.1  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0  NaN                 NaN  NaN    NaN         NaN         NaN         NaN
# 1  NaN              블랙 위도우  NaN    0.0         NaN         NaN         NaN
# 2  NaN                발신제한  NaN    0.0         NaN         NaN         NaN
# 3  NaN                  랑종  NaN    0.0         NaN         NaN         NaN
# 4  NaN               미드나이트  NaN    1.0         NaN         NaN         NaN
# 5  NaN                크루엘라  NaN    1.0         NaN         NaN         NaN
# 6  NaN             인 더 하이츠  NaN    2.0         NaN         NaN         NaN
# 7  NaN         콰이어트 플레이스 2  NaN    0.0         NaN         NaN         NaN
# 8  NaN          킬러의 보디가드 2  NaN    0.0         NaN         NaN         NaN
# 9  NaN              제8일의 밤  NaN    0.0         NaN         NaN         NaN
# 10 NaN                  루카  NaN    0.0         NaN         NaN         NaN
# ...

# %%
type(tables)
# Out:
# list

# %%
type(tables[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df_navermovie = tables[0]
df_navermovie
# Out:
#     순위                 영화명  변동폭  변동폭.1  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0  NaN                 NaN  NaN    NaN         NaN         NaN         NaN
# 1  NaN              블랙 위도우  NaN    0.0         NaN         NaN         NaN
# 2  NaN                발신제한  NaN    0.0         NaN         NaN         NaN
# 3  NaN                  랑종  NaN    0.0         NaN         NaN         NaN
# 4  NaN               미드나이트  NaN    1.0         NaN         NaN         NaN
# 5  NaN                크루엘라  NaN    1.0         NaN         NaN         NaN
# 6  NaN             인 더 하이츠  NaN    2.0         NaN         NaN         NaN
# 7  NaN         콰이어트 플레이스 2  NaN    0.0         NaN         NaN         NaN
# 8  NaN          킬러의 보디가드 2  NaN    0.0         NaN         NaN         NaN
# 9  NaN              제8일의 밤  NaN    0.0         NaN         NaN         NaN
# 10 NaN                  루카  NaN    0.0         NaN         NaN         NaN
# ...

# %%
df_navermovie['영화명']
# Out:
# 0                    NaN
# 1                 블랙 위도우
# 2                   발신제한
# 3                     랑종
# 4                  미드나이트
# 5                   크루엘라
# 6                인 더 하이츠
# 7            콰이어트 플레이스 2
# 8             킬러의 보디가드 2
# 9                 제8일의 밤
# 10                    루카
# 11                   NaN
# 12                투모로우 워
# 13             체르노빌 1986
# 14                  괴기맨숀
# 15    여고괴담 여섯번째 이야기 : 모교
# 16                빛나는 순간
# 17                   열아홉
# 18                    기담
# 19                  모가디슈
# 20                   싱크홀
# 21        컨저링 3: 악마가 시켰다
# 22                   NaN
# 23             더 퍼지: 포에버
# 24    이스케이프 룸 2: 노 웨이 아웃
# 25                    인질
# 26                아이스 로드
# 27                    셔터
# 28             다크 앤드 위키드
# 29       분노의 질주: 더 얼티메이트
# 30           미션 임파서블: 루벤
# 31                  비상선언
# 32             이번엔 잘 되겠지
# 33                   NaN
# 34     극장판 귀멸의 칼날: 무한열차편
# 35                  캐시트럭
# 36                  오필리아
# ...

# %%
df_navermovie['영화명'].notnull()
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11    False
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22    False
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33    False
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39     True
# 40     True
# 41     True
# 42     True
# 43     True
# 44    False
# 45     True
# 46     True
# 47     True
# 48     True
# 49     True
# 50     True
# 51     True
# 52     True
# 53     True
# 54     True
# 55    False
# Name: 영화명, dtype: bool

# %%
notnull_array = df_navermovie['영화명'].notnull()

# %%
df_navermovie['영화명'][notnull_array]
# Out:
# 1                 블랙 위도우
# 2                   발신제한
# 3                     랑종
# 4                  미드나이트
# 5                   크루엘라
# 6                인 더 하이츠
# 7            콰이어트 플레이스 2
# 8             킬러의 보디가드 2
# 9                 제8일의 밤
# 10                    루카
# 12                투모로우 워
# 13             체르노빌 1986
# 14                  괴기맨숀
# 15    여고괴담 여섯번째 이야기 : 모교
# 16                빛나는 순간
# 17                   열아홉
# 18                    기담
# 19                  모가디슈
# 20                   싱크홀
# 21        컨저링 3: 악마가 시켰다
# 23             더 퍼지: 포에버
# 24    이스케이프 룸 2: 노 웨이 아웃
# 25                    인질
# 26                아이스 로드
# 27                    셔터
# 28             다크 앤드 위키드
# 29       분노의 질주: 더 얼티메이트
# 30           미션 임파서블: 루벤
# 31                  비상선언
# 32             이번엔 잘 되겠지
# 34     극장판 귀멸의 칼날: 무한열차편
# 35                  캐시트럭
# 36                  오필리아
# 37         이보다 더 좋을 순 없다
# 38              우리는 매일매일
# 39              보스 베이비 2
# 40                곡성(哭聲)
# ...

# %%
df_movie = df_navermovie[['영화명']][notnull_array]
df_movie
# Out:
#                    영화명
# 1               블랙 위도우
# 2                 발신제한
# 3                   랑종
# 4                미드나이트
# 5                 크루엘라
# 6              인 더 하이츠
# 7          콰이어트 플레이스 2
# 8           킬러의 보디가드 2
# 9               제8일의 밤
# 10                  루카
# 12              투모로우 워
# 13           체르노빌 1986
# 14                괴기맨숀
# 15  여고괴담 여섯번째 이야기 : 모교
# 16              빛나는 순간
# 17                 열아홉
# 18                  기담
# 19                모가디슈
# 20                 싱크홀
# 21      컨저링 3: 악마가 시켰다
# 23           더 퍼지: 포에버
# 24  이스케이프 룸 2: 노 웨이 아웃
# 25                  인질
# 26              아이스 로드
# 27                  셔터
# 28           다크 앤드 위키드
# 29     분노의 질주: 더 얼티메이트
# 30         미션 임파서블: 루벤
# 31                비상선언
# 32           이번엔 잘 되겠지
# 34   극장판 귀멸의 칼날: 무한열차편
# 35                캐시트럭
# 36                오필리아
# 37       이보다 더 좋을 순 없다
# 38            우리는 매일매일
# 39            보스 베이비 2
# 40              곡성(哭聲)
# 41           콰이어트 플레이스
# 42             방법: 재차의
# ...

# %%
df_movie['순위'] = range(1,51)
df_movie
# Out:
#                    영화명  순위
# 1               블랙 위도우   1
# 2                 발신제한   2
# 3                   랑종   3
# 4                미드나이트   4
# 5                 크루엘라   5
# 6              인 더 하이츠   6
# 7          콰이어트 플레이스 2   7
# 8           킬러의 보디가드 2   8
# 9               제8일의 밤   9
# 10                  루카  10
# 12              투모로우 워  11
# 13           체르노빌 1986  12
# 14                괴기맨숀  13
# 15  여고괴담 여섯번째 이야기 : 모교  14
# 16              빛나는 순간  15
# 17                 열아홉  16
# 18                  기담  17
# 19                모가디슈  18
# 20                 싱크홀  19
# 21      컨저링 3: 악마가 시켰다  20
# 23           더 퍼지: 포에버  21
# 24  이스케이프 룸 2: 노 웨이 아웃  22
# 25                  인질  23
# 26              아이스 로드  24
# 27                  셔터  25
# 28           다크 앤드 위키드  26
# 29     분노의 질주: 더 얼티메이트  27
# 30         미션 임파서블: 루벤  28
# 31                비상선언  29
# 32           이번엔 잘 되겠지  30
# 34   극장판 귀멸의 칼날: 무한열차편  31
# 35                캐시트럭  32
# 36                오필리아  33
# ...

# %%
df_movie.set_index('순위')
# Out:
#                    영화명
# 순위
# 1               블랙 위도우
# 2                 발신제한
# 3                   랑종
# 4                미드나이트
# 5                 크루엘라
# 6              인 더 하이츠
# 7          콰이어트 플레이스 2
# 8           킬러의 보디가드 2
# 9               제8일의 밤
# 10                  루카
# 11              투모로우 워
# 12           체르노빌 1986
# 13                괴기맨숀
# 14  여고괴담 여섯번째 이야기 : 모교
# 15              빛나는 순간
# 16                 열아홉
# 17                  기담
# 18                모가디슈
# 19                 싱크홀
# 20      컨저링 3: 악마가 시켰다
# 21           더 퍼지: 포에버
# 22  이스케이프 룸 2: 노 웨이 아웃
# 23                  인질
# 24              아이스 로드
# 25                  셔터
# 26           다크 앤드 위키드
# 27     분노의 질주: 더 얼티메이트
# 28         미션 임파서블: 루벤
# 29                비상선언
# 30           이번엔 잘 되겠지
# 31   극장판 귀멸의 칼날: 무한열차편
# 32                캐시트럭
# 33                오필리아
# 34       이보다 더 좋을 순 없다
# 35            우리는 매일매일
# 36            보스 베이비 2
# 37              곡성(哭聲)
# 38           콰이어트 플레이스
# ...

# %%
df_movie.set_index('순위').to_csv
df_movie
# Out:
#                    영화명  순위
# 1               블랙 위도우   1
# 2                 발신제한   2
# 3                   랑종   3
# 4                미드나이트   4
# 5                 크루엘라   5
# 6              인 더 하이츠   6
# 7          콰이어트 플레이스 2   7
# 8           킬러의 보디가드 2   8
# 9               제8일의 밤   9
# 10                  루카  10
# 12              투모로우 워  11
# 13           체르노빌 1986  12
# 14                괴기맨숀  13
# 15  여고괴담 여섯번째 이야기 : 모교  14
# 16              빛나는 순간  15
# 17                 열아홉  16
# 18                  기담  17
# 19                모가디슈  18
# 20                 싱크홀  19
# 21      컨저링 3: 악마가 시켰다  20
# 23           더 퍼지: 포에버  21
# 24  이스케이프 룸 2: 노 웨이 아웃  22
# 25                  인질  23
# 26              아이스 로드  24
# 27                  셔터  25
# 28           다크 앤드 위키드  26
# 29     분노의 질주: 더 얼티메이트  27
# 30         미션 임파서블: 루벤  28
# 31                비상선언  29
# 32           이번엔 잘 되겠지  30
# 34   극장판 귀멸의 칼날: 무한열차편  31
# 35                캐시트럭  32
# 36                오필리아  33
# ...
